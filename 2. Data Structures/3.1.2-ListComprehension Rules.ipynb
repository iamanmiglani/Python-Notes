# %% [markdown]
# 1️⃣ The Universal Blueprint

# %% [markdown]
# [ expression  for item in iterable  if condition ]

# %% [markdown]
# 2️⃣ Break It Into 3 Blocks

# %% [markdown]
# | Block      | Meaning                | Example         |
# | ---------- | ---------------------- | --------------- |
# | Expression | What to output         | `x**2`          |
# | Loop       | Where values come from | `for x in nums` |
# | Filter     | Optional condition     | `if x%2==0`     |

# %% [markdown]
# [x**2 for x in nums if x%2==0]

# %% [markdown]
# 3️⃣ Rule #1 — Order Never Changes

# %% [markdown]
# [expression for item in iterable if condition]

# %% [markdown]
# 4️⃣ Rule #2 — Nested Loops Follow Loop Order

# %% [markdown]
# [num for row in matrix for num in row]

# %% [markdown]
# 5️⃣ Rule #3 — If-Else Goes in Expression (Not Filter)

# %% [markdown]
# A. Filter IF (removes items)

# %% [markdown]
# [x for x in nums if x%2==0]

# %% [markdown]
# B. Inline If-Else (transforms items)

# %% [markdown]
# ["Even" if x%2==0 else "Odd" for x in nums]

# %% [markdown]
# | Type    | Position          |
# | ------- | ----------------- |
# | Filter  | After loop        |
# | If-Else | Inside expression |

# %% [markdown]
# 6️⃣ Rule #4 — Multiple IFs Allowed

# %% [markdown]
# [x for x in nums if x>0 if x%2==0]

# %% [markdown]
# 7️⃣ Rule #5 — Expression Can Be Anything

# %% [markdown]
# Expression isn’t just x.

# %% [markdown]
# **Function call**: [f(x) for x in nums] <br>
# **Tuple**: [(x, x ** 2) for x in nums] <br>
# **Dictionary**: [{x: x ** 2} for x in nums] <br>
# **String operation**: [x.upper() for x in words] <br>

# %% [markdown]
# 8️⃣ Rule #6 — Read It Backwards

# %% [markdown]
# Best mental trick for interviews:
#
# Read comprehension from right → left.
#
# Example:

# %% [markdown]
# [x**2 for x in nums if x%2==0]

# %% [markdown]
# Think:
#
# Take x from nums
#
# Keep if even
#
# Output square

# %% [markdown]
# # Structural Patterns

# %% [markdown]
# Pattern 1 — Mapping <br>
# [expression for item in iterable]
#
# [x**2 for x in nums]

# %% [markdown]
# Pattern 2 — Filtering<br>
# [item for item in iterable if condition]

# %% [markdown]
# Pattern 3 — Map + Filter <br>
# [expression for item in iterable if condition]

# %% [markdown]
# Pattern 4 — Inline If-Else<br>
# [expr1 if cond else expr2 for item in iterable]

# %% [markdown]
# Pattern 5 — Nested Loops<br>
# [expr for a in A for b in B]

# %% [markdown]
# Pattern 6 — Nested + Condition <br>
# [expr for a in A for b in B if condition]

# %% [markdown]
# Pattern 7 — Multiple Filters <br>
# [expr for x in iterable if cond1 if cond2]
#
# [x for x in nums if x > 0 if x % 2 == 0]

# %% [markdown]
# Pattern 8 — Multiple Nested Loops (3+ levels) <br>
# [expr for a in A for b in B for c in C]
#
# Flatten 3D list

# %% [markdown]
# Pattern 9 — Nested Loops + Multiple Conditions <br>
# Combination of deep nesting + filters. <br>
# [expr for a in A for b in B if cond1 if cond2]
#
# Pairs whose sum < 10:<br>
# [(a,b) for a in A for b in B if a+b < 10]

# %% [markdown]
# Pattern 10 — Inline If-Else + Filter Together <br>
# Two different IF roles in one comprehension. <br>
# [expr1 if cond1 else expr2 for x in iterable if cond2]
#
#
# Label only positive numbers::<br>
# ["Even" if x%2==0 else "Odd"
#  for x in nums
#  if x > 0]

# %% [markdown]
# Pattern 11 — Function Calls Inside Expression <br>
# Expression can contain full logic. <br>
# [f(x) for x in data if g(x)]
#
#
# import math
# roots = [math.sqrt(x) for x in nums if x > 0]

# %% [markdown]
# Pattern 12 — Using enumerate() in Comprehension <br>
# [(i, x) for i, x in enumerate(iterable)]
#
#
# [(i, v) for i, v in enumerate(["a","b","c"])]

# %% [markdown]
# Pattern 13 — Using zip() in Comprehension <br>
# [expr for x, y in zip(A, B)]
#
#
# [x+y for x,y in zip([1,2],[3,4])]

# %% [markdown]
# Pattern 14 — Dictionary Comprehension (Structural Cousin) <br>
# Same grammar — different brackets <br>
# {key_expr: val_expr for item in iterable}
#
#
# {x: x**2 for x in nums}

# %% [markdown]
# Pattern 15 — Set Comprehension <br>
# {expr for x in iterable}
#
#
# {x**2 for x in nums}

# %% [markdown]
# Pattern 16 — Generator Comprehension <br>
# (expr for x in iterable if cond)

# %% [markdown]
# <br>
# <br>
# Basic:
# [expr for x in iterable]
#
# With filter:
# [expr for x in iterable if cond]
#
# If-Else:
# [expr1 if cond else expr2 for x in iterable]
#
# Nested:
# [expr for a in A for b in B]
#
# Nested + filter:
# [expr for a in A for b in B if cond]

# %% [markdown]
# # Patterns with uses

# %% [markdown]
# 🟦 2D Array Comprehensions

# %% [markdown]
# Flatten 2D matrix

# %%
matrix = [[1,2],[3,4],[5,6]]

flat = [x 
        for row in matrix
        for x in row]
flat
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# Even numbers from 2D matrix

# %%
lst = [x for row in matrix for x in row if x%2==0]
lst
# Out:
# [2, 4, 6]

# %% [markdown]
# Square every element (retain structure)

# %%
lst = [[x**2 for x in row] for row in matrix]
lst
# Out:
# [[1, 4], [9, 16], [25, 36]]

# %% [markdown]
# 🟪 3D Array Comprehensions

# %% [markdown]
# Flatten 3D array

# %%
arr = [[[-1, 2],[3, 4]],[[5, 6],[7, 8]]]

flat = [
    x
    for layer in arr
    for row in layer
    for x in row
]
flat
# Out:
# [-1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# Filter 3D array

# %%
lst = [x
 for layer in arr
 for row in layer
 for x in row
 if x > 0]

lst
# Out:
# [2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# Transform but retain structure

# %%
lst = [
  [
    [x**2 for x in row]
    for row in layer
  ]
  for layer in arr
]
lst
# Out:
# [[[1, 4], [9, 16]], [[25, 36], [49, 64]]]

# %% [markdown]
# 🧠 Structure Preservation vs Flattening

# %% [markdown]
# A. Flatten structure <br>
# Use chained loops:
# [x for row in matrix for x in row]

# %% [markdown]
# B. Preserve structure <br>
# Use nested comprehensions:[[x for x in row] for row in matrix]

# %% [markdown]
# | Goal           | Pattern               |
# | -------------- | --------------------- |
# | Flatten        | Nested loops          |
# | Preserve shape | Nested comprehensions |

# %% [markdown]
# 📚 Dictionary Comprehension

# %%
d = { 21: 1, 24: 2}
d
# Out:
# {21: 1, 24: 2}

# %%
print(d.keys())
print(d.values())
print(d.items())
# Out:
# dict_keys([21, 24])
# dict_values([1, 2])
# dict_items([(21, 1), (24, 2)])

# %% [markdown]
# Iterate keys

# %%
{k: k**2 for k in d}
# Out:
# {21: 441, 24: 576}

# %% [markdown]
# Iterate values

# %%
[v for v in d.values()]
# Out:
# [1, 2]

# %% [markdown]
# Iterate key–value pairs

# %%
{k:v for k,v in d.items()}
# Out:
# {21: 1, 24: 2}

# %% [markdown]
# Filter dictionary

# %%
{k:v for k,v in d.items() if v > 1}
# Out:
# {24: 2}

# %% [markdown]
# Swap keys & values

# %%
{v:k for k,v in d.items()}
# Out:
# {1: 21, 2: 24}

# %% [markdown]
# Nested dict comprehension

# %%
d = {
    "a": [1, 2, 3],
    "b": [4, 5]
}

# %%
{
  k: [x**2 for x in vals]
  for k, vals in d.items()
}
# Out:
# {'a': [1, 4, 9], 'b': [16, 25]}

# %% [markdown]
# 🧩 Mixed Data Structures

# %% [markdown]
# Dict → flattened list

# %%
[x
 for vals in d.values()
 for x in vals]
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Dict of matrices → flatten

# %%
d = {
    "a": [[1, 2],[ 3]],
    "b": [[4, 5],[2,3]]
}

# %%
[x
 for matrix in d.values()
 for row in matrix
 for x in row]
# Out:
# [1, 2, 3, 4, 5, 2, 3]

# %% [markdown]
# Nested comprehension (shape preserving)

# %% [markdown]
# [[expr for x in row] for row in matrix]

# %% [markdown]
# Deep nested comprehension

# %% [markdown]
# [
#   [[expr for x in row]
#    for row in layer]
#   for layer in data
# ]

# %% [markdown]
# Dict + nested list comprehension

# %% [markdown]
# {k: [expr for x in vals] for k, vals in d.items()}

# %% [markdown]
# Cross-structure nesting

# %% [markdown]
# [x
#  for k,v in d.items()
#  for x in v]
