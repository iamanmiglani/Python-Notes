# %% [markdown]
# Links: <br>
# https://www.educative.io/blog/8-common-data-structures-in-python-every-programmer-must-know <br>
# https://docs.python.org/3/tutorial/datastructures.html<br>
# https://www.datacamp.com/tutorial/data-structures-python<br>

# %% [markdown]
# Data structures are a way of organizing and storing data so that they can be accessed and worked with efficiently. They define the relationship between the data, and the operations that can be performed on the data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <br>

# %% [markdown]
# Algorithm Analysis (VERY IMPORTANT) <br>
# This is what separates coders from problem solvers.<br>
# Time Complexity<br>
# •	Big-O, Big-Ω, Big-Θ<br>
# •	Best, average, worst case<br>
# •	Amortized analysis<br>
# •	Growth rates comparison<br>
# Space Complexity<br>
# •	Auxiliary vs input space<br>
# •	Stack space in recursion<br>

# %% [markdown]
# Data structures are code structures for storing and organizing data that make it easier to modify, navigate, and access information. Data structures determine how data is collected, the functionality we can implement, and the relationships between data.<br>
# Each data structure offers a different way of completing tasks such as sorting, inserting and finding, but efficiency depends on the situation.<br>
# No data structure is ultimately better than another, but using one for a task it is not designed to support may lead to longer workflows, or worse, skewed data.<br>
#
# Python has 4 built-in data structures, lists, dictionaries, tuples, and sets.<br>
# Most data structures in Python are modified forms of these or use the built-in structures as their backbone.<br>
# •	List: Array-like structures that let you save a set of mutable objects of the same type to a variable.<br>
# •	Tuple: Tuples are immutable lists, meaning the elements cannot be changed. It’s declared with parenthesis instead of square brackets.<br>
# •	Set: Sets are unordered collections, meaning that elements are unindexed and have no set sequence. They’re declared with curly braces.<br>
# •	Dictionary (dict): Similar to hashmap or hash tables in other languages, a dictionary is a collection of key/value pairs. You initialize an empty dictionary with empty curly braces and fill it with colon separated keys and values. All keys are unique, immutable objects.<br>
